# %%
import pandas as pd

# %%
# Load the dataset
netflix = pd.read_csv("netflix_data.csv")

# %%
movies_1990s = netflix[(netflix["release_year"] >= 1990) & (netflix["release_year"] < 2000)]
short_movies_list = []
for index, movie in movies_1990s.iterrows():
    if movie["duration"] < 90:
        short_movies_list.append(movie)

print("1990s short movies:")
print(short_movies_list)
# Out:
# 1990s short movies:
# [show_id                                                      s211
# type                                                        Movie
# title                                      A Night at the Roxbury
# director                                         John Fortenberry
# cast            Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...
# country                                             United States
# date_added                                       December 1, 2019
# release_year                                                 1998
# duration                                                       82
# description     After a run-in with Richard Grieco, dimwits Do...
# genre                                                    Comedies
# Name: 145, dtype: object, show_id                                                      s487
# type                                                        Movie
# title                          An American Tail: Fievel Goes West
# director                              Phil Nibbelink, Simon Wells
# cast            Philip Glasser, James Stewart, Erica Yohn, Cat...
# country                                             United States
# date_added                                          April 1, 2018
# release_year                                                 1991
# duration                                                       75
# description     Fievel and his family head west for what turns...
# genre                                                    Children
# Name: 333, dtype: object, show_id                                                      s488
# type                                                        Movie
# title           An American Tail: The Mystery of the Night Mon...
# director                                             Larry Latham
# cast            Thomas Dekker, Lacey Chabert, Jane Singer, Neh...
# country                                             United States
# date_added                                          April 1, 2018
# release_year                                                 1999
# duration                                                       75
# description     When a monster goes on a mouse-napping spree i...
# genre                                                    Children
# Name: 334, dtype: object, show_id                                                      s624
# type                                                        Movie
# title                           Auschwitz: Blueprints of Genocide
# director                                            Mike Rossiter
# cast                                                  Roy Marsden
# country                                            United Kingdom
# date_added                                       January 19, 2019
# release_year                                                 1994
# duration                                                       49
# description     Newly released KGB files expose evidence provi...
# genre                                               Documentaries
# Name: 428, dtype: object, show_id                                                      s709
# type                                                        Movie
# title                                                       Balto
# director                                              Simon Wells
# cast            Kevin Bacon, Bob Hoskins, Bridget Fonda, Jim C...
# country                                             United States
# date_added                                          April 1, 2018
# release_year                                                 1995
# duration                                                       78
# description     Balto, who is half wolf and half dog, endures ...
# genre                                                    Children
# Name: 479, dtype: object, show_id                                                      s782
# type                                                        Movie
# title                           Bean: The Ultimate Disaster Movie
# director                                                Mel Smith
# cast            Rowan Atkinson, Peter MacNicol, John Mills, Pa...
# country                                            United Kingdom
# date_added                                         August 1, 2018
# release_year                                                 1997
# duration                                                       89
# description     Disaster-prone Mr. Bean is sent to Los Angeles...
# genre                                                    Comedies
# Name: 530, dtype: object, show_id                                                      s795
# type                                                        Movie
# title                             Beavis and Butt-head Do America
# director                                               Mike Judge
# cast            Mike Judge, Bruce Willis, Demi Moore, Cloris L...
# country                                             United States
# date_added                                      November 20, 2019
# release_year                                                 1996
# duration                                                       81
# description     After realizing that their boob tube is gone, ...
# genre                                                    Comedies
# Name: 536, dtype: object, show_id                                                      s796
# type                                                        Movie
# title                                                 Bebe's Kids
# director                                           Bruce W. Smith
# cast            Faizon Love, Vanessa Bell Calloway, Wayne Coll...
# country                                             United States
# date_added                                      November 20, 2019
# release_year                                                 1992
# duration                                                       73
# description     When ladies' man Robin meets Jamika, he falls ...
# genre                                                    Comedies
# Name: 537, dtype: object, show_id                                                      s920
# type                                                        Movie
# title                                 Bill Hicks: One Night Stand
# director                                         John Fortenberry
# cast                                                   Bill Hicks
# country                                            United Kingdom
# date_added                                      December 31, 2018
# release_year                                                 1991
# duration                                                       28
# description     Bill Hicks remembers a wild night in 1989 and ...
# genre                                                    Stand-Up
# Name: 622, dtype: object, show_id                                                      s922
# type                                                        Movie
# title                                      Bill Hicks: Relentless
# director                                              Chris Bould
# cast                                                   Bill Hicks
# country                                            United Kingdom
# date_added                                      December 31, 2018
# release_year                                                 1992
# duration                                                       61
# description     In one of his most iconic performances, late c...
# genre                                                    Stand-Up
# Name: 623, dtype: object, show_id                                                      s923
# type                                                        Movie
# title                                     Bill Hicks: Revelations
# director                                              Chris Bould
# cast                                                   Bill Hicks
# country                                            United Kingdom
# date_added                                      December 31, 2018
# release_year                                                 1993
# duration                                                       56
# description     In his final recorded special, the iconoclasti...
# genre                                                    Stand-Up
# Name: 624, dtype: object, show_id                                                     s1703
# type                                                        Movie
# title                             Denis Leary: No Cure For Cancer
# director                                                Ted Demme
# cast                                                  Denis Leary
# country                                             United States
# date_added                                         August 8, 2017
# release_year                                                 1992
# duration                                                       62
# description     In the stand-up performance that made him a le...
# genre                                                    Stand-Up
# Name: 1084, dtype: object, show_id                                                     s2026
# type                                                        Movie
# title                            Escape from the "Liberty" Cinema
# director                                      Wojciech Marczewski
# cast            Janusz Gajos, Zbigniew Zamachowski, Teresa Mar...
# country                                                    Poland
# date_added                                        October 1, 2019
# release_year                                                 1990
# duration                                                       88
# description     Artistic rebellion ignites at the movies when ...
# genre                                                    Comedies
# Name: 1281, dtype: object, show_id                                                     s2039
# type                                                        Movie
# title                                   EVANGELION: DEATH (TRUE)²
# director                                             Hideaki Anno
# cast            Megumi Ogata, Kotono Mitsuishi, Megumi Hayashi...
# country                                                     Japan
# date_added                                          June 21, 2019
# release_year                                                 1998
# duration                                                       69
# description     Fifteen years after the Second Impact, apathet...
# genre                                                      Action
# Name: 1288, dtype: object, show_id                                                     s2708
# type                                                        Movie
# title                                                        Hero
# director                                               Corey Yuen
# cast            Takeshi Kaneshiro, Yuen Biao, Valerie Chow, Je...
# country                                                 Hong Kong
# date_added                                         August 1, 2018
# release_year                                                 1997
# duration                                                       89
# description     A pugilist from Shantung struggles to rise to ...
# genre                                                      Action
# Name: 1698, dtype: object, show_id                                                     s3157
# type                                                        Movie
# title           Jerry Seinfeld: I'm Telling You for the Last Time
# director                                            Marty Callner
# cast                                               Jerry Seinfeld
# country                                             United States
# date_added                                       January 30, 2018
# release_year                                                 1998
# duration                                                       69
# description     Months after his classic TV sitcom ends, the l...
# genre                                                    Stand-Up
# Name: 1982, dtype: object, show_id                                                     s3335
# type                                                      TV Show
# title                                    Ken Burns: The Civil War
# director                                                Ken Burns
# cast            Sam Waterston, Julie Harris, Jason Robards, Mo...
# country                                             United States
# date_added                                      February 22, 2017
# release_year                                                 1990
# duration                                                        1
# description     Ken Burns's documentary depicts the action of ...
# genre                                                  Docuseries
# Name: 2110, dtype: object, show_id                                                     s3718
# type                                                        Movie
# title                                           Look Out, Officer
# director                                               Sze Yu Lau
# cast            Stephen Chow, Bill Tung, Stanley Sui-Fan Fung,...
# country                                                 Hong Kong
# date_added                                        August 16, 2018
# release_year                                                 1990
# duration                                                       88
# description     An officer killed on the job returns to Earth ...
# genre                                                      Action
# Name: 2328, dtype: object, show_id                                                     s3797
# type                                                        Movie
# title                                                  Loving You
# director                                               Johnnie To
# cast            Lau Ching Wan, Carman Lee, Tsung-Hua To, Chung...
# country                                                 Hong Kong
# date_added                                        August 16, 2018
# release_year                                                 1995
# duration                                                       79
# description     Struggling in a loveless marriage, a hard-drin...
# genre                                                      Dramas
# Name: 2371, dtype: object, show_id                                                     s4646
# type                                                        Movie
# title                                               One Last Shot
# director                                         Mike Clattenburg
# cast               Robb Wells, John Paul Tremblay, John Dunsworth
# country                                                    Canada
# date_added                                        August 24, 2018
# release_year                                                 1998
# duration                                                       31
# description     In this low-budget short film, two best buddie...
# genre                                                    Comedies
# Name: 2908, dtype: object, show_id                                                     s4787
# type                                                        Movie
# title                                                Passenger 57
# director                                              Kevin Hooks
# cast            Wesley Snipes, Bruce Payne, Tom Sizemore, Alex...
# country                                             United States
# date_added                                        January 1, 2021
# release_year                                                 1992
# duration                                                       84
# description     Air marshal John Cutter must stop notorious te...
# genre                                                      Action
# Name: 2993, dtype: object, show_id                                                     s4871
# type                                                        Movie
# title                                          Pizza, birra, faso
# director                    Israel Adrián Caetano, Bruno Stagnaro
# cast            Héctor Anglada, Jorge Sesán, Pamela Jordán, Ad...
# country                                                 Argentina
# date_added                                         March 15, 2018
# release_year                                                 1998
# duration                                                       81
# description     A group of hardscrabble young thieves in Argen...
# genre                                                      Dramas
# Name: 3052, dtype: object, show_id                                                     s5299
# type                                                        Movie
# title                                         Rumble in the Bronx
# director                                             Stanley Tong
# cast            Jackie Chan, Anita Mui, Françoise Yip, Bill Tu...
# country                                                 Hong Kong
# date_added                                       November 1, 2019
# release_year                                                 1995
# duration                                                       89
# description     During a visit to the Bronx to help out at his...
# genre                                                      Action
# Name: 3297, dtype: object, show_id                                                     s5359
# type                                                        Movie
# title                      Sam Kinison: Family Entertainment Hour
# director                                         Walter C. Miller
# cast                                                  Sam Kinison
# country                                             United States
# date_added                                      December 31, 2018
# release_year                                                 1991
# duration                                                       49
# description     Comic Sam Kinison lets it rip with this perfor...
# genre                                                    Stand-Up
# Name: 3337, dtype: object, show_id                                                     s5360
# type                                                        Movie
# title                                  Sam Kinison: Live in Vegas
# director                                         Walter C. Miller
# cast                                                  Sam Kinison
# country                                             United States
# date_added                                      December 31, 2018
# release_year                                                 1991
# duration                                                       71
# description     Standup legend Sam Kinison is at his screaming...
# genre                                                    Stand-Up
# Name: 3338, dtype: object, show_id                                                     s5438
# type                                                        Movie
# title                                 Scooby-Doo on Zombie Island
# director          Hiroshi Aoyama, Kazumi Fukushima, Jim Stenstrum
# cast            Scott Innes, Billy West, Mary Kay Bergman, Fra...
# country                                             United States
# date_added                                      December 15, 2019
# release_year                                                 1998
# duration                                                       77
# description     When Daphne's TV show does a segment on real m...
# genre                                                    Children
# Name: 3393, dtype: object, show_id                                                     s5858
# type                                                        Movie
# title                                               Stuart Little
# director                                              Rob Minkoff
# cast            Michael J. Fox, Jonathan Lipnicki, Geena Davis...
# country                                                   Germany
# date_added                                        January 1, 2020
# release_year                                                 1999
# duration                                                       85
# description     Mr. and Mrs. Little want to adopt a brother fo...
# genre                                                    Children
# Name: 3649, dtype: object, show_id                                                     s5915
# type                                                        Movie
# title                                                   Superstar
# director                                          Bruce McCulloch
# cast            Molly Shannon, Will Ferrell, Elaine Hendrix, H...
# country                                             United States
# date_added                                      November 20, 2019
# release_year                                                 1999
# duration                                                       82
# description     A socially awkward Catholic schoolgirl vows to...
# genre                                                    Comedies
# Name: 3679, dtype: object, show_id                                                     s5989
# type                                                        Movie
# title                                                      Tarzan
# director                                   Chris Buck, Kevin Lima
# cast            Tony Goldwyn, Minnie Driver, Glenn Close, Bria...
# country                                             United States
# date_added                                          June 23, 2018
# release_year                                                 1999
# duration                                                       89
# description     After being shipwrecked off the African coast,...
# genre                                                    Children
# Name: 3726, dtype: object, show_id                                                     s6015
# type                                                        Movie
# title           Teenage Mutant Ninja Turtles II: The Secret of...
# director                                         Michael Pressman
# cast            Paige Turco, David Warner, Mark Caso, Michelan...
# country                                             United States
# date_added                                        January 1, 2020
# release_year                                                 1991
# duration                                                       88
# description     The evil Shredder decides that ooze is what gi...
# genre                                                    Children
# Name: 3743, dtype: object, show_id                                                     s6114
# type                                                        Movie
# title                                         The Bare-Footed Kid
# director                                               Johnnie To
# cast            Aaron Kwok, Lung Ti, Maggie Cheung, Chien-lien...
# country                                                 Hong Kong
# date_added                                        August 16, 2018
# release_year                                                 1993
# duration                                                       83
# description     While working at a family friend's business, a...
# genre                                                      Action
# Name: 3806, dtype: object, show_id                                                     s6330
# type                                                        Movie
# title                                       The End of Evangelion
# director                           Hideaki Anno, Kazuya Tsurumaki
# cast            Megumi Ogata, Kotono Mitsuishi, Megumi Hayashi...
# country                                                     Japan
# date_added                                          June 21, 2019
# release_year                                                 1997
# duration                                                       87
# description     Seele orders an all-out attack on NERV, aiming...
# genre                                                      Action
# Name: 3943, dtype: object, show_id                                                     s6628
# type                                                        Movie
# title                                                The Mad Monk
# director                                                Johnny To
# cast            Stephen Chow, Maggie Cheung, Anthony Wong Chau...
# country                                                 Hong Kong
# date_added                                        August 16, 2018
# release_year                                                 1993
# duration                                                       85
# description     To avoid punishment for his misdeeds, an arrog...
# genre                                                    Comedies
# Name: 4124, dtype: object, show_id                                                     s6840
# type                                                        Movie
# title                                           The Rugrats Movie
# director                            Igor Kovalyov, Norton Virgien
# cast            Elizabeth Daily, Christine Cavanaugh, Kath Sou...
# country                                             United States
# date_added                                        October 1, 2019
# release_year                                                 1998
# duration                                                       81
# description     When his baby brother Dil is born, Tommy Pickl...
# genre                                                    Children
# Name: 4252, dtype: object, show_id                                                     s7090
# type                                                        Movie
# title                                     Tim Allen: Men Are Pigs
# director                                              Ellen Brown
# cast                                                    Tim Allen
# country                                             United States
# date_added                                      December 31, 2018
# release_year                                                 1990
# duration                                                       30
# description     Standup comedian Tim Allen delivers a set dedi...
# genre                                                    Stand-Up
# Name: 4411, dtype: object]
